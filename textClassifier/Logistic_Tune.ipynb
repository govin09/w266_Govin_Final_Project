# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_pickle('data/label_renamed.pkl')

# %%
df['Dominant_Topic'].nunique()
# Out:
# 11

# %%
df
# Out:
#          Document_No                          Dominant_Topic  \
# 0                  0                Destruction/Consequences
# 1                  1                              News/Media
# 2                  2                        Belief/Sentiment
# 3                  3                           Arctic/Icecap
# 4                  4  ClimateChangeIsReal/FightClimateChange
# ...              ...                                     ...
# 2999958      2999958                           Arctic/Icecap
# 2999966      2999966                        Belief/Sentiment
# 2999975      2999975                Action/Efforts/Awareness
# 2999981      2999981                        Belief/Sentiment
# 2999985      2999985  ClimateChangeIsReal/FightClimateChange
#
#          Topic_Perc_Contrib  \
# 0                    0.2297
# 1                    0.2824
# 2                    0.4131
# 3                    0.5074
# 4                    0.7851
# ...                     ...
# 2999958              0.2953
# 2999966              0.2710
# 2999975              0.0667
# 2999981              0.2273
# 2999985              0.6069
#
#                                                   Keywords  \
# 0        global, warming, park, stop, joshua, admin, na...
# 1        threat, news, happening, temperature, day, fac...
# 2        world, trump, head, president, study, way, sup...
# 3        it, time, year, arctic, planet, weather, probl...
# 4        climate, change, zinke, real, human, talk, wor...
# ...                                                    ...
# 2999958  it, time, year, arctic, planet, weather, probl...
# 2999966  world, trump, head, president, study, way, sup...
# 2999975  amp, action, leader, tweet, thanks, away, summ...
# 2999981  dont, good, like, think, people, want, know, l...
# 2999985  climate, change, zinke, real, human, talk, wor...
#
#                                                       Text  \
# 0        [global, wine, production, reach, new, low, ch...
# 1        [im, dismissing, crazy, conspiracy, im, dismis...
# 2                               [let, turn, thing, around]
# 3        [new, approach, globalwarming, projection, reg...
# 4        [child, estimated, bear, burden, disease, rela...
# ...                                                    ...
# 2999958  [thank, important, thread, major, danger, planet]
# 2999966  [decision, unilaterally, dismiss, agreement, s...
# 2999975                                    [sarah, sander]
# 2999981  [let, moment, realize, people, denying, climat...
# 2999985  [m, scared, climate, change, ai, im, terrified...
#
#                                                   hashtags
# 0                              climatechange wine plastics
# 1                                                      NaN
# 2        ProtectWhatYouLove ActOnClimate Sustainability...
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 2999958                                      ClimateChange
# 2999966                                                NaN
# 2999975  ALSenate RoyMoore FollowTheWhiteRabbit QAnon U...
# 2999981                                                NaN
# 2999985                                                NaN
#
# [799038 rows x 6 columns]

# %%
# Fix Text column (from list to string)
df['TextString'] = [' '.join(map(str, l)) for l in df['Text']]

# %%
df.head()
# Out:
#    Document_No                          Dominant_Topic  Topic_Perc_Contrib  \
# 0            0                Destruction/Consequences              0.2297
# 1            1                              News/Media              0.2824
# 2            2                        Belief/Sentiment              0.4131
# 3            3                           Arctic/Icecap              0.5074
# 4            4  ClimateChangeIsReal/FightClimateChange              0.7851
#
#                                             Keywords  \
# 0  global, warming, park, stop, joshua, admin, na...
# 1  threat, news, happening, temperature, day, fac...
# 2  world, trump, head, president, study, way, sup...
# 3  it, time, year, arctic, planet, weather, probl...
# 4  climate, change, zinke, real, human, talk, wor...
#
#                                                 Text  \
# 0  [global, wine, production, reach, new, low, ch...
# 1  [im, dismissing, crazy, conspiracy, im, dismis...
# 2                         [let, turn, thing, around]
# 3  [new, approach, globalwarming, projection, reg...
# 4  [child, estimated, bear, burden, disease, rela...
#
#                                             hashtags  \
# 0                        climatechange wine plastics
# 1                                                NaN
# 2  ProtectWhatYouLove ActOnClimate Sustainability...
# 3                                                NaN
# 4                                                NaN
#
#                                           TextString
# 0  global wine production reach new low changing ...
# 1  im dismissing crazy conspiracy im dismissing t...
# 2                              let turn thing around
# 3  new approach globalwarming projection regional...
# 4  child estimated bear burden disease related cl...

# %%
# from sklearn.feature_extraction.text import TfidfTransformer
X_train, X_test, y_train, y_test = train_test_split(df['TextString'], df['Dominant_Topic'], random_state = 0)

# %%
import sklearn.metrics as metrics
lr_f1 = []

# Find f1 score for the c values below
c_value = np.concatenate([np.arange(0.01,0.1,0.01),np.arange(0.1,1,0.1), np.arange(1,11,1)])
for c in c_value:
    vectorizer = CountVectorizer()
    vtrain = vectorizer.fit_transform(X_train)
    vdev = vectorizer.transform(X_test)
    lrmodel = LogisticRegression(C=c, penalty='l2', multi_class='auto', solver='liblinear', max_iter=1000)
    lrmodel.fit(vtrain, y_train)
    dev_pred = lrmodel.predict(vdev)
    f1 = metrics.f1_score(y_test, dev_pred, average='weighted')
    lr_f1.append(f1)
    sum_sq_weight = np.square(lrmodel.coef_).sum(axis=1)
    print("\tFor c-value = %f --> F1 score = %f" % (c, f1))
    for i in range(0,4):
        print("\t\tClass %d: %f" % (i,sum_sq_weight[i]))

# Find highest F1 score
print("\n\tc = %f has the highest f1 score %f" % (c_value[np.argmax(lr_f1)], max(lr_f1)))
# Out:
# 	For c-value = 0.010000 --> F1 score = 0.768296
# 		Class 0: 347.990029
# 		Class 1: 256.939879
# 		Class 2: 250.243741
# 		Class 3: 384.367942
# 	For c-value = 0.020000 --> F1 score = 0.793576
# 		Class 0: 583.943256
# 		Class 1: 438.572572
# 		Class 2: 417.159202
# 		Class 3: 669.959608
# 	For c-value = 0.030000 --> F1 score = 0.804864
# 		Class 0: 780.048937
# 		Class 1: 590.825878
# 		Class 2: 554.362216
# 		Class 3: 912.629120
# 	For c-value = 0.040000 --> F1 score = 0.810762
# 		Class 0: 956.190849
# 		Class 1: 726.446208
# 		Class 2: 676.693205
# 		Class 3: 1130.008753
# 	For c-value = 0.050000 --> F1 score = 0.814865
# 		Class 0: 1121.284086
# 		Class 1: 851.079604
# 		Class 2: 790.226015
# 		Class 3: 1331.116987
# 	For c-value = 0.060000 --> F1 score = 0.817476
# 		Class 0: 1279.057912
# 		Class 1: 968.220668
# 		Class 2: 898.466390
# 		Class 3: 1520.473839
# 	For c-value = 0.070000 --> F1 score = 0.819444
# 		Class 0: 1433.244666
# 		Class 1: 1080.141437
# 		Class 2: 1003.632588
# 		Class 3: 1700.035574
# 	For c-value = 0.080000 --> F1 score = 0.820971
# 		Class 0: 1584.523410
# 		Class 1: 1187.331903
# 		Class 2: 1106.878527
# 		Class 3: 1876.377682
# 	For c-value = 0.090000 --> F1 score = 0.822296
# 		Class 0: 1736.469234
# 		Class 1: 1290.566214
# 		Class 2: 1208.427761
# 		Class 3: 2046.489879
# 	For c-value = 0.100000 --> F1 score = 0.823316
# 		Class 0: 1886.689529
# 		Class 1: 1391.824603
# 		Class 2: 1309.838097
# 		Class 3: 2212.432827
# 	For c-value = 0.200000 --> F1 score = 0.826794
# 		Class 0: 3447.716895
# 		Class 1: 2338.101356
# 		Class 2: 2343.494804
# 		Class 3: 3795.048074
# 	For c-value = 0.300000 --> F1 score = 0.827259
# 		Class 0: 5157.946233
# 		Class 1: 3254.098250
# 		Class 2: 3453.474209
# 		Class 3: 5363.350902
# 	For c-value = 0.400000 --> F1 score = 0.826795
# 		Class 0: 6997.920213
# 		Class 1: 4180.311857
# 		Class 2: 4650.575109
# 		Class 3: 6968.677324
# 	For c-value = 0.500000 --> F1 score = 0.826200
# 		Class 0: 8932.022835
# 		Class 1: 5120.275062
# 		Class 2: 5907.975206
# 		Class 3: 8610.672322
# 	For c-value = 0.600000 --> F1 score = 0.825268
# 		Class 0: 10994.829752
# 		Class 1: 6078.793801
# 		Class 2: 7210.662639
# 		Class 3: 10289.485174
# 	For c-value = 0.700000 --> F1 score = 0.824563
# 		Class 0: 13116.635922
# 		Class 1: 7035.254398
# 		Class 2: 8566.560232
# 		Class 3: 12023.384049
# 	For c-value = 0.800000 --> F1 score = 0.823807
# 		Class 0: 15257.407687
# 		Class 1: 8030.543861
# 		Class 2: 9935.581836
# 		Class 3: 13767.670379
# 	For c-value = 0.900000 --> F1 score = 0.823183
# 		Class 0: 17493.114075
# 		Class 1: 9011.946905
# 		Class 2: 11357.641251
# 		Class 3: 15509.628257
# 	For c-value = 1.000000 --> F1 score = 0.822575
# 		Class 0: 19721.887960
# 		Class 1: 10019.396671
# 		Class 2: 12772.770864
# 		Class 3: 17324.859814
# 	For c-value = 2.000000 --> F1 score = 0.816826
# 		Class 0: 42745.102926
# 		Class 1: 20089.583685
# 		Class 2: 27438.967762
# 		Class 3: 35392.141535
# 	For c-value = 3.000000 --> F1 score = 0.812939
# 		Class 0: 65258.151943
# 		Class 1: 29834.199507
# 		Class 2: 41779.328905
# 		Class 3: 52964.969837
# 	For c-value = 4.000000 --> F1 score = 0.809948
# 		Class 0: 86324.063620
# 		Class 1: 39094.180153
# 		Class 2: 55323.551568
# 		Class 3: 69386.952700
# 	For c-value = 5.000000 --> F1 score = 0.807162
# 		Class 0: 105704.236173
# 		Class 1: 47566.355187
# 		Class 2: 67990.094886
# 		Class 3: 84738.091171
# 	For c-value = 6.000000 --> F1 score = 0.804801
# 		Class 0: 124187.355168
# 		Class 1: 55964.324515
# 		Class 2: 80020.127951
# 		Class 3: 98889.518428
# 	For c-value = 7.000000 --> F1 score = 0.802819
# 		Class 0: 141159.224489
# 		Class 1: 63708.357247
# 		Class 2: 91048.071865
# 		Class 3: 112370.471110
# 	For c-value = 8.000000 --> F1 score = 0.800989
# 		Class 0: 157325.824338
# 		Class 1: 71059.880335
# 		Class 2: 101491.376221
# 		Class 3: 125052.203146
# 	For c-value = 9.000000 --> F1 score = 0.799511
# 		Class 0: 172108.588514
# 		Class 1: 77890.467866
# 		Class 2: 111437.139337
# 		Class 3: 136748.200866
# 	For c-value = 10.000000 --> F1 score = 0.798033
# 		Class 0: 186872.280241
# 		Class 1: 84747.729851
# 		Class 2: 121451.909882
# 		Class 3: 148000.376018
#
# 	c = 0.300000 has the highest f1 score 0.827259

# %%
lrmodel = LogisticRegression(C=0.3, penalty='l2', multi_class='auto', solver='liblinear', max_iter=1000)
lrmodel.fit(vtrain, y_train)
dev_pred = lrmodel.predict(vdev)

# %%
accu = metrics.accuracy_score(y_test, dev_pred)
print("Accuracy = %f" % accu)
# Out:
# Accuracy = 0.829130
